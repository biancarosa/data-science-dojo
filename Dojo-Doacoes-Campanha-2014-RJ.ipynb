# %%
import pandas as pd
import numpy as np
import matplotlib 
# %matplotlib inline

# %%
df = pd.read_csv('receitas_candidatos_2014_RJ.txt', sep=';', encoding='ISO-8859-1')

# %%
df.head()
# Out:
#    Cód. Eleição         Desc. Eleição         Data e hora  \
# 0           143  Eleições Gerais 2014  24/06/201615:00:39
# 1           143  Eleições Gerais 2014  24/06/201615:00:39
# 2           143  Eleições Gerais 2014  24/06/201615:00:39
# 3           143  Eleições Gerais 2014  24/06/201615:00:39
# 4           143  Eleições Gerais 2014  24/06/201615:00:39
#
#    CNPJ Prestador Conta  Sequencial Candidato  UF Sigla  Partido  \
# 0        20582303000177          190000001647  RJ        PC do B
# 1        20567564000118          190000000557  RJ             PT
# 2        20582303000177          190000001647  RJ        PC do B
# 3        20603092000101          190000002966  RJ        PC do B
# 4        20564772000163          190000000537  RJ             PT
#
#    Numero candidato              Cargo               Nome candidato  \
# 0             65365  Deputado Estadual      LUCIANA MARINA DA SILVA
# 1             13200  Deputado Estadual             ROGÉRIO COUTINHO
# ...

# %%
df.describe()
# Out:
#        Cód. Eleição  CNPJ Prestador Conta  Sequencial Candidato  \
# count       46174.0          4.617400e+04          4.617400e+04
# mean          143.0          2.058257e+13          1.900000e+11
# std             0.0          2.415829e+10          7.910947e+02
# min           143.0          2.054534e+13          1.900000e+11
# 25%           143.0          2.057754e+13          1.900000e+11
# 50%           143.0          2.058082e+13          1.900000e+11
# 75%           143.0          2.058269e+13          1.900000e+11
# max           143.0          2.114218e+13          1.900000e+11
#
#        Numero candidato  CPF do candidato  Número candidato doador
# count      46174.000000      4.617400e+04             46174.000000
# mean       16889.791658      4.261916e+10             16889.791658
# std        19727.515105      3.092862e+10             19727.515105
# min           10.000000      3.512703e+06                10.000000
# ...

# %%
list(df.columns.values)
# Out:
# [u'C\xf3d. Elei\xe7\xe3o',
#  u'Desc. Elei\xe7\xe3o',
#  u'Data e hora',
#  u'CNPJ Prestador Conta',
#  u'Sequencial Candidato',
#  u'UF',
#  u'Sigla  Partido',
#  u'Numero candidato',
#  u'Cargo',
#  u'Nome candidato',
#  u'CPF do candidato',
#  u'Numero Recibo Eleitoral',
#  u'Numero do documento',
#  u'CPF/CNPJ do doador',
#  u'Nome do doador',
#  u'Nome do doador (Receita Federal)',
#  u'Sigla UE doador',
#  u'N\xfamero partido doador',
#  u'N\xfamero candidato doador',
#  u'Cod setor econ\xf4mico do doador',
#  u'Setor econ\xf4mico do doador',
#  u'Data da receita',
#  u'Valor receita',
#  u'Tipo receita',
#  u'Fonte recurso',
#  u'Especie recurso',
#  u'Descricao da receita',
#  u'CPF/CNPJ do doador origin\xe1rio',
#  u'Nome do doador origin\xe1rio',
#  u'Tipo doador origin\xe1rio',
#  u'Setor econ\xf4mico do doador origin\xe1rio',
#  u'Nome do doador origin\xe1rio (Receita Federal)']

# %%
df1 = df[['Nome candidato', 'Valor receita', 'Numero candidato']]

# %%
print df1
# Out:
#                                Nome candidato Valor receita  Numero candidato
# 0                     LUCIANA MARINA DA SILVA           560             65365
# 1                            ROGÉRIO COUTINHO          1865             13200
# 2                     LUCIANA MARINA DA SILVA          1275             65365
# 3                 CLAUDIO SIQUEIRA DE FREITAS         992,5             65051
# 4                     ADILIO SALVADOR SARAIVA         992,5             13843
# 5                         ROBSON CAMPOS LEITE           560             13013
# 6                 MARCOS PAULO COSTA DA SILVA          1865             13111
# 7                 LUCIANA GONÇALVES DE NOVAES          1865             13535
# 8      ADOLPHO KONDER HOMEM DE CARVALHO FILHO           560             65000
# 9                        CARLOS ROBERTO PAIVA         412,5             13100
# 10                       CARLOS MINC BAUMFELD        1441,8             13001
# ...

# %%
df2 = df1['Valor receita'].replace(',','.')

# %%
df2 = df1['Valor receita'].replace(',','.').convert_objects(convert_numeric=True)
# Out:
# /home/bianca/dev/data-science-dojo/venv/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':

# %%
df1['Valor receita'].convert_objects(convert_numeric=True)
# Out:
# /home/bianca/dev/data-science-dojo/venv/lib/python2.7/site-packages/ipykernel/__main__.py:1: FutureWarning: convert_objects is deprecated.  Use the data-type specific converters pd.to_datetime, pd.to_timedelta and pd.to_numeric.
#   if __name__ == '__main__':
# 0           560.0
# 1          1865.0
# 2          1275.0
# 3             NaN
# 4             NaN
# 5           560.0
# 6          1865.0
# 7          1865.0
# 8           560.0
# 9             NaN
# 10            NaN
# 11          825.0
# 12            NaN
# 13         1275.0
# 14            NaN
# 15          280.0
# 16            NaN
# 17          280.0
# 18          560.0
# 19         2150.0
# 20            NaN
# 21            NaN
# 22            NaN
# 23         1865.0
# 24            NaN
# 25         1865.0
# 26          280.0
# 27          560.0
# 28          280.0
# 29            NaN
#            ...
# 46144     15000.0
# 46145    500000.0
# 46146    350000.0
# 46147    200000.0
# 46148      2400.0
# 46149       513.0
# ...

# %%
df1['Valor receita'].replace(',','.')
# Out:
# 0            560
# 1           1865
# 2           1275
# 3          992,5
# 4          992,5
# 5            560
# 6           1865
# 7           1865
# 8            560
# 9          412,5
# 10        1441,8
# 11           825
# 12         992,5
# 13          1275
# 14         992,5
# 15           280
# 16         992,5
# 17           280
# 18           560
# 19          2150
# 20         412,5
# 21         992,5
# 22        1603,8
# 23          1865
# 24         412,5
# 25          1865
# 26           280
# 27           560
# 28           280
# 29         412,5
#           ...
# 46144      15000
# 46145     500000
# 46146     350000
# 46147     200000
# 46148       2400
# 46149        513
# 46150         90
# 46151         90
# 46152         90
# 46153        340
# 46154    1766,67
# 46155    1413,33
# 46156    1201,33
# 46157    1766,66
# 46158     3533,3
# 46159       2250
# 46160        150
# 46161       1875
# 46162        225
# 46163        450
# 46164       2250
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-77-613234957adc> in <module>()
# ----> 1 df1['Valor receita'].plot()
#
# /home/bianca/dev/data-science-dojo/venv/lib/python2.7/site-packages/pandas/tools/plotting.pyc in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    3564                            colormap=colormap, table=table, yerr=yerr,
#    3565                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 3566                            **kwds)
#    3567     __call__.__doc__ = plot_series.__doc__
#    3568
#
# ...
